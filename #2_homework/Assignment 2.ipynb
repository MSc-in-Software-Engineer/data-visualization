# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('melb_data.csv')

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (13580, 21)

# %% [markdown]
# __For better undestanding of features, please see: https://datawrapper.dwcdn.net/hHuXG/4/
#
# ## <font color='Red'> Questions </font>
#
# <br>__1) see how many unique values does the dataframe have? - <font color='purple'> 5 points </font>__

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 2.2+ MB

# %% [markdown]
# __2) describe the null values of each features - <font color='purple'> 5 points </font>__

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# __3) Deal with the na values: try to apply the best strategy. That is, if the number of nan values are too much then remove the column if the column is not necessary. Otherwise, you can remove them from the dataset or you can fill na with an appropriate strategy. Save the rearranged form as df2 without changing df - <font color='purple'> 10 points </font>__

# %%
df2 = df.dropna(axis=0, how="any")
df2.dropna(how='any', inplace=True)
# Out:
# /var/folders/bw/tgvmyyzj1lx_nl3bvvgnf3fh0000gn/T/ipykernel_80901/705354651.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(how='any', inplace=True)

# %%
df2.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %% [markdown]
# __4) Select the 'Suburb', 'Address', 'Rooms', 'Type', 'Price','Distance', 'Bedroom2', 'Bathroom', 'Car',
#     'Regionname', 'Propertycount' columns to describe df3: <font color='purple'> 5 points </font>__

# %%
df3 = df2[["Suburb", "Address", "Rooms", "Type", "Price", "Distance", "Bedroom2", "Bathroom", "Car"]]
print(f"df3 columns; \n\n{df3.columns}")
# Out:
# df3 columns;
#
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Distance', 'Bedroom2',
#        'Bathroom', 'Car'],
#       dtype='object')

# %% [markdown]
# __5) Describe the statistics of the dataset: <font color='purple'> 10 points </font>__

# %%
# without cathegorical data
df3.describe(include="all")
# Out:
#            Suburb           Address        Rooms  Type         Price  \
# count        6196              6196  6196.000000  6196  6.196000e+03
# unique        287              6117          NaN     3           NaN
# top     Reservoir  36 Aberfeldie St          NaN     h           NaN
# freq          154                 3          NaN  4088           NaN
# mean          NaN               NaN     2.931407   NaN  1.068828e+06
# std           NaN               NaN     0.971079   NaN  6.751564e+05
# min           NaN               NaN     1.000000   NaN  1.310000e+05
# 25%           NaN               NaN     2.000000   NaN  6.200000e+05
# 50%           NaN               NaN     3.000000   NaN  8.800000e+05
# 75%           NaN               NaN     4.000000   NaN  1.325000e+06
# max           NaN               NaN     8.000000   NaN  9.000000e+06
#
#            Distance     Bedroom2     Bathroom          Car
# count   6196.000000  6196.000000  6196.000000  6196.000000
# unique          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN
# mean       9.751097     2.902034     1.576340     1.573596
# std        5.612065     0.970055     0.711362     0.929947
# min        0.000000     0.000000     1.000000     0.000000
# 25%        5.900000     2.000000     1.000000     1.000000
# 50%        9.000000     3.000000     1.000000     1.000000
# 75%       12.400000     3.000000     2.000000     2.000000
# max       47.400000     9.000000     8.000000    10.000000

# %%
# with categorical data
print(
    f"\n\nfloat describe; \n\n{df3.describe(include=float)}"
    f"\n\nobject describe; \n\n{df3.describe(include=object)}"
    f"\n\nint describe; \n\n{df3.describe(include=int)}"
)
# Out:
# float describe;
#
#               Price     Distance     Bedroom2     Bathroom          Car
# count  6.196000e+03  6196.000000  6196.000000  6196.000000  6196.000000
# mean   1.068828e+06     9.751097     2.902034     1.576340     1.573596
# std    6.751564e+05     5.612065     0.970055     0.711362     0.929947
# min    1.310000e+05     0.000000     0.000000     1.000000     0.000000
# 25%    6.200000e+05     5.900000     2.000000     1.000000     1.000000
# 50%    8.800000e+05     9.000000     3.000000     1.000000     1.000000
# 75%    1.325000e+06    12.400000     3.000000     2.000000     2.000000
# max    9.000000e+06    47.400000     9.000000     8.000000    10.000000
#
# object describe;
#
#            Suburb           Address  Type
# count        6196              6196  6196
# unique        287              6117     3
# top     Reservoir  36 Aberfeldie St     h
# freq          154                 3  4088
#
# int describe;
#
#              Rooms
# count  6196.000000
# mean      2.931407
# std       0.971079
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       8.000000

# %% [markdown]
# __6) Describe the counts of unique values of 'Suburb','Type','Regionname', 'Propertycount'   <font color='purple'> 10 points </font>__

# %%
desc_unique_df = df[["Suburb", "Type", "Regionname", "Propertycount"]].describe(include="all")
desc_unique_df
# Out:
#            Suburb   Type             Regionname  Propertycount
# count       13580  13580                  13580   13580.000000
# unique        314      3                      8            NaN
# top     Reservoir      h  Southern Metropolitan            NaN
# freq          359   9449                   4695            NaN
# mean          NaN    NaN                    NaN    7454.417378
# std           NaN    NaN                    NaN    4378.581772
# min           NaN    NaN                    NaN     249.000000
# 25%           NaN    NaN                    NaN    4380.000000
# 50%           NaN    NaN                    NaN    6555.000000
# 75%           NaN    NaN                    NaN   10331.000000
# max           NaN    NaN                    NaN   21650.000000

# %% [markdown]
# __7) Describe the outliers by box plot: Write a a loop for the object columns of df3 whose number of unique values is less than 10.  <font color='purple'> 15 points </font>__

# %%
plt.figure(figsize=(12,8))
loop_results = df3.loc[:, df3.apply(lambda x: x.nunique()) <= 10]
loop_results.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# __8) Describe the correlation of df3: <font color='purple'> 10 points </font>__

# %%
kendall_corr = df3.corr(method="kendall")
pearson_corr = df3.corr(method="pearson")

print(f"\n\nKendal Correlation;\n\n{kendall_corr}\n")

sns.heatmap(kendall_corr.corr(), annot=True)
plt.show()

print(f"\n\nPearson_corr Correlation;\n\n{pearson_corr}\n")

sns.heatmap(pearson_corr.corr(), annot=True)
plt.show()
# Out:
# Kendal Correlation;
#
#              Rooms     Price  Distance  Bedroom2  Bathroom       Car
# Rooms     1.000000  0.472399  0.254104  0.946007  0.561631  0.423779
# Price     0.472399  1.000000 -0.080167  0.457664  0.384778  0.235185
# Distance  0.254104 -0.080167  1.000000  0.260004  0.121148  0.268989
# Bedroom2  0.946007  0.457664  0.260004  1.000000  0.555438  0.425769
# Bathroom  0.561631  0.384778  0.121148  0.555438  1.000000  0.355742
# Car       0.423779  0.235185  0.268989  0.425769  0.355742  1.000000
# Pearson_corr Correlation;
#
#              Rooms     Price  Distance  Bedroom2  Bathroom       Car
# Rooms     1.000000  0.533505  0.283885  0.951793  0.613853  0.422526
# Price     0.533505  1.000000 -0.148867  0.514561  0.503922  0.261507
# Distance  0.283885 -0.148867  1.000000  0.290242  0.124530  0.273615
# Bedroom2  0.951793  0.514561  0.290242  1.000000  0.617751  0.425726
# Bathroom  0.613853  0.503922  0.124530  0.617751  1.000000  0.340808
# Car       0.422526  0.261507  0.273615  0.425726  0.340808  1.000000

# %% [markdown]
# __10) Describe the address # of rooms, # of bathrooms, distance for the highest Price house?: <font color='purple'> 10 points </font>__

# %% [markdown]
# __11) Is there any signaficant relation between Regionname and Price? - <font color='purple'> 20 points </font>__
